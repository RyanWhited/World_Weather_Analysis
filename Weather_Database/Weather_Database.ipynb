# %%
from citipy import citipy
import pandas as pd
import numpy as np
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_country = city_weather["sys"]["country"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | bafq
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | campbell river
# Processing Record 12 of Set 1 | polohy
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | tautira
# Processing Record 19 of Set 1 | ketchikan
# Processing Record 20 of Set 1 | ishigaki
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | aginskoye
# Processing Record 24 of Set 1 | akdepe
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | bama
# Processing Record 27 of Set 1 | kozhva
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | barraute
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | sistranda
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | anyksciai
# Processing Record 35 of Set 1 | batagay-alyta
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | oksfjord
# Processing Record 38 of Set 1 | izumo
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | teguldet
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | zhezkazgan
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | gurupa
# Processing Record 46 of Set 1 | lakatoro
# Processing Record 47 of Set 1 | alnashi
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | george
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | vazante
# Processing Record 4 of Set 2 | amapa
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | broome
# Processing Record 8 of Set 2 | villefranche-de-rouergue
# Processing Record 9 of Set 2 | okhotsk
# Processing Record 10 of Set 2 | rodrigues alves
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | houma
# Processing Record 13 of Set 2 | bandarbeyla
# Processing Record 14 of Set 2 | kapuskasing
# Processing Record 15 of Set 2 | jumla
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | acarau
# Processing Record 18 of Set 2 | solsvik
# City not found. Skipping...
# Processing Record 19 of Set 2 | karpathos
# Processing Record 20 of Set 2 | rawson
# Processing Record 21 of Set 2 | praia
# Processing Record 22 of Set 2 | mao
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | muros
# Processing Record 26 of Set 2 | malaya serdoba
# Processing Record 27 of Set 2 | port macquarie
# Processing Record 28 of Set 2 | kavaratti
# Processing Record 29 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | stavrovo
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | polson
# Processing Record 37 of Set 2 | korla
# Processing Record 38 of Set 2 | praya
# Processing Record 39 of Set 2 | victor harbor
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | kenora
# Processing Record 43 of Set 2 | saint-pierre
# Processing Record 44 of Set 2 | jabinyanah
# Processing Record 45 of Set 2 | blackwater
# Processing Record 46 of Set 2 | talcahuano
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | killybegs
# Processing Record 49 of Set 2 | fort nelson
# Processing Record 50 of Set 2 | stoughton
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | savonlinna
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | pallisa
# Processing Record 6 of Set 3 | jacareacanga
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | mount gambier
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | heiligenhafen
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | dingle
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | bonthe
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | tasiilaq
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | ayan
# Processing Record 22 of Set 3 | wewak
# Processing Record 23 of Set 3 | richards bay
# Processing Record 24 of Set 3 | katsuura
# Processing Record 25 of Set 3 | luanda
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | porto novo
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | paamiut
# Processing Record 33 of Set 3 | galesong
# Processing Record 34 of Set 3 | san quintin
# Processing Record 35 of Set 3 | mazatlan
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | cedar city
# Processing Record 38 of Set 3 | nicolas bravo
# Processing Record 39 of Set 3 | ormara
# Processing Record 40 of Set 3 | bredasdorp
# Processing Record 41 of Set 3 | kilindoni
# Processing Record 42 of Set 3 | guarapari
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | matay
# Processing Record 45 of Set 3 | slupsk
# Processing Record 46 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | oranjemund
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | khirkiya
# Processing Record 1 of Set 4 | villa bruzual
# Processing Record 2 of Set 4 | ciudad bolivar
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | lufkin
# Processing Record 8 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 4 | hailar
# Processing Record 10 of Set 4 | klaksvik
# Processing Record 11 of Set 4 | kieta
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | geraldton
# Processing Record 14 of Set 4 | capaccio
# Processing Record 15 of Set 4 | keflavik
# Processing Record 16 of Set 4 | edd
# Processing Record 17 of Set 4 | torbay
# Processing Record 18 of Set 4 | ratnagiri
# Processing Record 19 of Set 4 | viedma
# Processing Record 20 of Set 4 | nikolskoye
# Processing Record 21 of Set 4 | verkhoyansk
# Processing Record 22 of Set 4 | san cristobal
# Processing Record 23 of Set 4 | honningsvag
# Processing Record 24 of Set 4 | seddon
# Processing Record 25 of Set 4 | beringovskiy
# Processing Record 26 of Set 4 | rosetta
# Processing Record 27 of Set 4 | guerrero negro
# Processing Record 28 of Set 4 | manado
# Processing Record 29 of Set 4 | kericho
# Processing Record 30 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 4 | cody
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | puerto del rosario
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | saint-philippe
# Processing Record 36 of Set 4 | aviles
# Processing Record 37 of Set 4 | svetlyy
# Processing Record 38 of Set 4 | mackay
# Processing Record 39 of Set 4 | kismayo
# Processing Record 40 of Set 4 | grand gaube
# Processing Record 41 of Set 4 | san policarpo
# Processing Record 42 of Set 4 | rorvik
# Processing Record 43 of Set 4 | aguimes
# Processing Record 44 of Set 4 | warrington
# Processing Record 45 of Set 4 | chifeng
# Processing Record 46 of Set 4 | ostrovnoy
# Processing Record 47 of Set 4 | danjiangkou
# Processing Record 48 of Set 4 | kloulklubed
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | astana
# Processing Record 1 of Set 5 | veraval
# Processing Record 2 of Set 5 | sinnamary
# Processing Record 3 of Set 5 | namibe
# Processing Record 4 of Set 5 | pacific grove
# Processing Record 5 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 5 | zhaotong
# Processing Record 7 of Set 5 | san andres
# Processing Record 8 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 9 of Set 5 | lusambo
# Processing Record 10 of Set 5 | carutapera
# Processing Record 11 of Set 5 | muzhi
# Processing Record 12 of Set 5 | purpe
# Processing Record 13 of Set 5 | hualmay
# Processing Record 14 of Set 5 | faanui
# Processing Record 15 of Set 5 | dubbo
# Processing Record 16 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 5 | mocuba
# Processing Record 18 of Set 5 | malakal
# Processing Record 19 of Set 5 | orocue
# Processing Record 20 of Set 5 | emerald
# Processing Record 21 of Set 5 | usinsk
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | barao de melgaco
# Processing Record 24 of Set 5 | sayat
# Processing Record 25 of Set 5 | panaba
# Processing Record 26 of Set 5 | yuanping
# Processing Record 27 of Set 5 | mwense
# Processing Record 28 of Set 5 | mombetsu
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 5 | barentu
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | ust-kuyga
# Processing Record 33 of Set 5 | zamboanga
# Processing Record 34 of Set 5 | los llanos de aridane
# Processing Record 35 of Set 5 | port hardy
# Processing Record 36 of Set 5 | teul
# City not found. Skipping...
# Processing Record 37 of Set 5 | okha
# Processing Record 38 of Set 5 | tiksi
# Processing Record 39 of Set 5 | listvyanskiy
# Processing Record 40 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 5 | jalor
# Processing Record 42 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | jiayuguan
# Processing Record 44 of Set 5 | naliya
# Processing Record 45 of Set 5 | tessalit
# Processing Record 46 of Set 5 | bajil
# Processing Record 47 of Set 5 | vila velha
# Processing Record 48 of Set 5 | aklavik
# Processing Record 49 of Set 5 | siderno
# Processing Record 50 of Set 5 | kapit
# Processing Record 1 of Set 6 | malpe
# Processing Record 2 of Set 6 | providencia
# Processing Record 3 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 4 of Set 6 | tocopilla
# Processing Record 5 of Set 6 | awjilah
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | vestmanna
# Processing Record 8 of Set 6 | hervey bay
# Processing Record 9 of Set 6 | bairiki
# Processing Record 10 of Set 6 | ternate
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | jinchang
# Processing Record 13 of Set 6 | norman wells
# Processing Record 14 of Set 6 | yumen
# Processing Record 15 of Set 6 | chalus
# Processing Record 16 of Set 6 | kruisfontein
# Processing Record 17 of Set 6 | taga
# Processing Record 18 of Set 6 | bambous virieux
# Processing Record 19 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 6 | anadyr
# Processing Record 21 of Set 6 | sladkovo
# Processing Record 22 of Set 6 | staraya poltavka
# Processing Record 23 of Set 6 | patterson
# Processing Record 24 of Set 6 | deputatskiy
# Processing Record 25 of Set 6 | beihai
# Processing Record 26 of Set 6 | asheville
# Processing Record 27 of Set 6 | eydhafushi
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | tiznit
# Processing Record 30 of Set 6 | saint joseph
# Processing Record 31 of Set 6 | lisakovsk
# Processing Record 32 of Set 6 | chulman
# Processing Record 33 of Set 6 | kilrush
# Processing Record 34 of Set 6 | maniitsoq
# Processing Record 35 of Set 6 | carndonagh
# Processing Record 36 of Set 6 | rockport
# Processing Record 37 of Set 6 | cordoba
# Processing Record 38 of Set 6 | upernavik
# Processing Record 39 of Set 6 | meulaboh
# Processing Record 40 of Set 6 | ekhabi
# Processing Record 41 of Set 6 | nome
# Processing Record 42 of Set 6 | rock sound
# Processing Record 43 of Set 6 | lenger
# Processing Record 44 of Set 6 | lerwick
# Processing Record 45 of Set 6 | noumea
# Processing Record 46 of Set 6 | ler
# Processing Record 47 of Set 6 | lagoa
# Processing Record 48 of Set 6 | puerto madero
# Processing Record 49 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 6 | haines junction
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | hit
# Processing Record 3 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 7 | ahmadpur east
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | half moon bay
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | khasan
# Processing Record 9 of Set 7 | dhenkanal
# Processing Record 10 of Set 7 | ornes
# Processing Record 11 of Set 7 | college
# Processing Record 12 of Set 7 | juquia
# Processing Record 13 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 7 | shimoda
# Processing Record 15 of Set 7 | serra talhada
# Processing Record 16 of Set 7 | airai
# Processing Record 17 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 7 | flinders
# Processing Record 20 of Set 7 | worland
# Processing Record 21 of Set 7 | gazni
# City not found. Skipping...
# Processing Record 22 of Set 7 | severo-kurilsk
# Processing Record 23 of Set 7 | tzaneen
# Processing Record 24 of Set 7 | buraydah
# Processing Record 25 of Set 7 | hereford
# Processing Record 26 of Set 7 | lodhran
# Processing Record 27 of Set 7 | westport
# Processing Record 28 of Set 7 | abatskoye
# Processing Record 29 of Set 7 | taunggyi
# Processing Record 30 of Set 7 | malokakhovka
# Processing Record 31 of Set 7 | samarai
# Processing Record 32 of Set 7 | chernoyerkovskaya
# Processing Record 33 of Set 7 | prince rupert
# Processing Record 34 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 7 | robertsonpet
# Processing Record 36 of Set 7 | artyom
# Processing Record 37 of Set 7 | sidney
# Processing Record 38 of Set 7 | nipawin
# Processing Record 39 of Set 7 | vostok
# Processing Record 40 of Set 7 | tarbes
# Processing Record 41 of Set 7 | vila franca do campo
# Processing Record 42 of Set 7 | moscow
# Processing Record 43 of Set 7 | taitung
# Processing Record 44 of Set 7 | oussouye
# Processing Record 45 of Set 7 | tymovskoye
# Processing Record 46 of Set 7 | sayyan
# Processing Record 47 of Set 7 | la romana
# Processing Record 48 of Set 7 | itaituba
# Processing Record 49 of Set 7 | churapcha
# Processing Record 50 of Set 7 | contamana
# Processing Record 1 of Set 8 | aksu
# Processing Record 2 of Set 8 | vredendal
# Processing Record 3 of Set 8 | mugla
# Processing Record 4 of Set 8 | gold coast
# Processing Record 5 of Set 8 | torrington
# Processing Record 6 of Set 8 | sacama
# Processing Record 7 of Set 8 | valparaiso
# Processing Record 8 of Set 8 | izhma
# Processing Record 9 of Set 8 | riwaka
# Processing Record 10 of Set 8 | semey
# Processing Record 11 of Set 8 | kuah
# Processing Record 12 of Set 8 | diffa
# Processing Record 13 of Set 8 | saint charles
# Processing Record 14 of Set 8 | kolobovo
# Processing Record 15 of Set 8 | port lincoln
# Processing Record 16 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 8 | tulsipur
# Processing Record 18 of Set 8 | morwell
# Processing Record 19 of Set 8 | pokhara
# Processing Record 20 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 8 | palmer
# Processing Record 22 of Set 8 | imbituba
# Processing Record 23 of Set 8 | svecha
# Processing Record 24 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 8 | olafsvik
# Processing Record 26 of Set 8 | aktas
# Processing Record 27 of Set 8 | constitucion
# Processing Record 28 of Set 8 | el viso del alcor
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | morondava
# Processing Record 31 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 8 | mpika
# Processing Record 33 of Set 8 | sisimiut
# Processing Record 34 of Set 8 | laguna
# Processing Record 35 of Set 8 | cockburn town
# Processing Record 36 of Set 8 | egvekinot
# Processing Record 37 of Set 8 | collie
# Processing Record 38 of Set 8 | asaba
# Processing Record 39 of Set 8 | ostrogozhsk
# Processing Record 40 of Set 8 | kenai
# Processing Record 41 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 8 | lashio
# Processing Record 43 of Set 8 | havre
# Processing Record 44 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 8 | bambanglipuro
# Processing Record 46 of Set 8 | meaford
# Processing Record 47 of Set 8 | calama
# Processing Record 48 of Set 8 | kavieng
# Processing Record 49 of Set 8 | lac du bonnet
# Processing Record 50 of Set 8 | victoria
# Processing Record 1 of Set 9 | yerbogachen
# Processing Record 2 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 9 | lima
# Processing Record 4 of Set 9 | pochutla
# Processing Record 5 of Set 9 | huarmey
# Processing Record 6 of Set 9 | cape coast
# Processing Record 7 of Set 9 | khatassy
# Processing Record 8 of Set 9 | laem sing
# Processing Record 9 of Set 9 | asahikawa
# Processing Record 10 of Set 9 | farafangana
# Processing Record 11 of Set 9 | comodoro rivadavia
# Processing Record 12 of Set 9 | tamworth
# Processing Record 13 of Set 9 | henties bay
# Processing Record 14 of Set 9 | jalu
# Processing Record 15 of Set 9 | neryungri
# Processing Record 16 of Set 9 | sao filipe
# Processing Record 17 of Set 9 | tual
# Processing Record 18 of Set 9 | sichevita
# Processing Record 19 of Set 9 | broken hill
# Processing Record 20 of Set 9 | jojoima
# Processing Record 21 of Set 9 | kanniyakumari
# Processing Record 22 of Set 9 | koboko
# Processing Record 23 of Set 9 | gidam
# Processing Record 24 of Set 9 | paita
# Processing Record 25 of Set 9 | nelson bay
# Processing Record 26 of Set 9 | kudahuvadhoo
# Processing Record 27 of Set 9 | terrace bay
# Processing Record 28 of Set 9 | esil
# Processing Record 29 of Set 9 | aranos
# Processing Record 30 of Set 9 | narsaq
# Processing Record 31 of Set 9 | sabang
# Processing Record 32 of Set 9 | sechura
# Processing Record 33 of Set 9 | kajaani
# Processing Record 34 of Set 9 | luwuk
# Processing Record 35 of Set 9 | yar-sale
# Processing Record 36 of Set 9 | quatre cocos
# Processing Record 37 of Set 9 | vanimo
# Processing Record 38 of Set 9 | xining
# Processing Record 39 of Set 9 | bereda
# Processing Record 40 of Set 9 | bakel
# Processing Record 41 of Set 9 | tupelo
# Processing Record 42 of Set 9 | mitu
# Processing Record 43 of Set 9 | amalapuram
# Processing Record 44 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 45 of Set 9 | bud
# Processing Record 46 of Set 9 | lompoc
# Processing Record 47 of Set 9 | bubaque
# Processing Record 48 of Set 9 | stromness
# Processing Record 49 of Set 9 | gayny
# Processing Record 50 of Set 9 | karaidel
# Processing Record 1 of Set 10 | waitati
# Processing Record 2 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 3 of Set 10 | almeirim
# Processing Record 4 of Set 10 | kulhudhuffushi
# Processing Record 5 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 10 | waipawa
# Processing Record 7 of Set 10 | buala
# Processing Record 8 of Set 10 | sept-iles
# Processing Record 9 of Set 10 | almaznyy
# Processing Record 10 of Set 10 | amla
# Processing Record 11 of Set 10 | sorland
# Processing Record 12 of Set 10 | samarinda
# Processing Record 13 of Set 10 | canon city
# Processing Record 14 of Set 10 | muana
# Processing Record 15 of Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 16 of Set 10 | awbari
# Processing Record 17 of Set 10 | cabo san lucas
# Processing Record 18 of Set 10 | cervo
# Processing Record 19 of Set 10 | healesville
# Processing Record 20 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 21 of Set 10 | palora
# Processing Record 22 of Set 10 | goderich
# Processing Record 23 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 10 | sukhinichi
# Processing Record 25 of Set 10 | pisco
# Processing Record 26 of Set 10 | doha
# Processing Record 27 of Set 10 | salinopolis
# Processing Record 28 of Set 10 | purmerend
# Processing Record 29 of Set 10 | virginia beach
# Processing Record 30 of Set 10 | alofi
# Processing Record 31 of Set 10 | saint anthony
# Processing Record 32 of Set 10 | boma
# Processing Record 33 of Set 10 | concordia
# Processing Record 34 of Set 10 | safranbolu
# Processing Record 35 of Set 10 | zhuhai
# Processing Record 36 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 10 | bulaevo
# Processing Record 38 of Set 10 | vardo
# Processing Record 39 of Set 10 | coahuayana
# Processing Record 40 of Set 10 | shebunino
# Processing Record 41 of Set 10 | skjervoy
# Processing Record 42 of Set 10 | inhambane
# Processing Record 43 of Set 10 | mahebourg
# Processing Record 44 of Set 10 | bria
# Processing Record 45 of Set 10 | dinguiraye
# Processing Record 46 of Set 10 | domoni
# Processing Record 47 of Set 10 | bauska
# Processing Record 48 of Set 10 | yeppoon
# Processing Record 49 of Set 10 | epalinges
# Processing Record 50 of Set 10 | acapulco
# Processing Record 1 of Set 11 | tortoli
# Processing Record 2 of Set 11 | thunder bay
# Processing Record 3 of Set 11 | sembe
# Processing Record 4 of Set 11 | ambon
# Processing Record 5 of Set 11 | marevo
# Processing Record 6 of Set 11 | douentza
# Processing Record 7 of Set 11 | amga
# Processing Record 8 of Set 11 | solton
# Processing Record 9 of Set 11 | touros
# Processing Record 10 of Set 11 | inuvik
# Processing Record 11 of Set 11 | bilma
# Processing Record 12 of Set 11 | yulara
# Processing Record 13 of Set 11 | beian
# Processing Record 14 of Set 11 | west helena
# Processing Record 15 of Set 11 | khudumelapye
# Processing Record 16 of Set 11 | kano
# Processing Record 17 of Set 11 | puerto madryn
# Processing Record 18 of Set 11 | southbridge
# Processing Record 19 of Set 11 | denau
# City not found. Skipping...
# Processing Record 20 of Set 11 | champerico
# Processing Record 21 of Set 11 | kahului
# Processing Record 22 of Set 11 | kyzyl-suu
# Processing Record 23 of Set 11 | brae
# Processing Record 24 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | port keats
# Processing Record 26 of Set 11 | tucuma
# Processing Record 27 of Set 11 | bose
# Processing Record 28 of Set 11 | worpswede
# Processing Record 29 of Set 11 | priboj
# Processing Record 30 of Set 11 | saint-louis
# Processing Record 31 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 11 | nishihara
# Processing Record 33 of Set 11 | junction city
# Processing Record 34 of Set 11 | maceio
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | pitimbu
# Processing Record 37 of Set 11 | burnie
# Processing Record 38 of Set 11 | san buenaventura
# Processing Record 39 of Set 11 | gimli
# Processing Record 40 of Set 11 | mezhdurechensk
# Processing Record 41 of Set 11 | shumyachi
# Processing Record 42 of Set 11 | namatanai
# Processing Record 43 of Set 11 | eltham
# Processing Record 44 of Set 11 | marion
# Processing Record 45 of Set 11 | atambua
# Processing Record 46 of Set 11 | cataguases
# Processing Record 47 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 11 | mizque
# Processing Record 49 of Set 11 | kuito
# Processing Record 50 of Set 11 | bathsheba
# Processing Record 1 of Set 12 | ligayan
# Processing Record 2 of Set 12 | belmonte
# Processing Record 3 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 12 | bagdarin
# Processing Record 5 of Set 12 | les cayes
# Processing Record 6 of Set 12 | lensk
# Processing Record 7 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 8 of Set 12 | dosso
# Processing Record 9 of Set 12 | panixtlahuaca
# City not found. Skipping...
# Processing Record 10 of Set 12 | wa
# City not found. Skipping...
# Processing Record 11 of Set 12 | ouadda
# Processing Record 12 of Set 12 | solginskiy
# Processing Record 13 of Set 12 | havelock
# Processing Record 14 of Set 12 | phan thiet
# Processing Record 15 of Set 12 | victoria point
# Processing Record 16 of Set 12 | mabaruma
# Processing Record 17 of Set 12 | warmbad
# Processing Record 18 of Set 12 | hamilton
# Processing Record 19 of Set 12 | kuching
# Processing Record 20 of Set 12 | khash
# Processing Record 21 of Set 12 | daru
# Processing Record 22 of Set 12 | lehututu
# Processing Record 23 of Set 12 | mount isa
# Processing Record 24 of Set 12 | genhe
# Processing Record 25 of Set 12 | lianzhou
# Processing Record 26 of Set 12 | trimbak
# Processing Record 27 of Set 12 | freeport
# Processing Record 28 of Set 12 | gat
# Processing Record 29 of Set 12 | kyrylivka
# Processing Record 30 of Set 12 | grand-santi
# Processing Record 31 of Set 12 | bataipora
# Processing Record 32 of Set 12 | kampot
# Processing Record 33 of Set 12 | coihaique
# Processing Record 34 of Set 12 | nortelandia
# Processing Record 35 of Set 12 | black river
# Processing Record 36 of Set 12 | gilbues
# Processing Record 37 of Set 12 | bongandanga
# Processing Record 38 of Set 12 | praxedis guerrero
# Processing Record 39 of Set 12 | helena
# Processing Record 40 of Set 12 | zhuanghe
# Processing Record 41 of Set 12 | sozopol
# Processing Record 42 of Set 12 | aberdeen
# Processing Record 43 of Set 12 | tenenkou
# Processing Record 44 of Set 12 | crotone
# Processing Record 45 of Set 12 | kununurra
# Processing Record 46 of Set 12 | gujan-mestras
# Processing Record 47 of Set 12 | marawi
# Processing Record 48 of Set 12 | sloboda
# Processing Record 49 of Set 12 | ada
# Processing Record 50 of Set 12 | isangel
# Processing Record 1 of Set 13 | conde
# Processing Record 2 of Set 13 | tygda
# Processing Record 3 of Set 13 | pasni
# Processing Record 4 of Set 13 | ust-omchug
# Processing Record 5 of Set 13 | juye
# Processing Record 6 of Set 13 | novobirilyussy
# Processing Record 7 of Set 13 | tilichiki
# Processing Record 8 of Set 13 | sitrah
# Processing Record 9 of Set 13 | torrevieja
# Processing Record 10 of Set 13 | aktau
# Processing Record 11 of Set 13 | anloga
# Processing Record 12 of Set 13 | kutoarjo
# Processing Record 13 of Set 13 | vrangel
# Processing Record 14 of Set 13 | shelburne
# Processing Record 15 of Set 13 | harper
# Processing Record 16 of Set 13 | manacapuru
# Processing Record 17 of Set 13 | gboko
# Processing Record 18 of Set 13 | karasjok
# Processing Record 19 of Set 13 | salalah
# Processing Record 20 of Set 13 | caravelas
# Processing Record 21 of Set 13 | luau
# Processing Record 22 of Set 13 | autun
# Processing Record 23 of Set 13 | mayor pablo lagerenza
# Processing Record 24 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 13 | tommot
# Processing Record 26 of Set 13 | bilibino
# Processing Record 27 of Set 13 | katobu
# Processing Record 28 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 13 | shenjiamen
# Processing Record 30 of Set 13 | neiafu
# Processing Record 31 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 13 | labrea
# Processing Record 33 of Set 13 | whitehaven
# Processing Record 34 of Set 13 | reo
# Processing Record 35 of Set 13 | shingu
# Processing Record 36 of Set 13 | san ramon
# Processing Record 37 of Set 13 | melville
# Processing Record 38 of Set 13 | vanavara
# Processing Record 39 of Set 13 | baculin
# Processing Record 40 of Set 13 | katha
# City not found. Skipping...
# Processing Record 41 of Set 13 | coquimbo
# Processing Record 42 of Set 13 | zeya
# Processing Record 43 of Set 13 | yonibana
# Processing Record 44 of Set 13 | butwal
# Processing Record 45 of Set 13 | zapolyarnyy
# Processing Record 46 of Set 13 | kondagaon
# Processing Record 47 of Set 13 | ust-nera
# Processing Record 48 of Set 13 | komsomolskiy
# Processing Record 49 of Set 13 | mehriz
# Processing Record 50 of Set 13 | machico
# Processing Record 1 of Set 14 | hasaki
# Processing Record 2 of Set 14 | nenjiang
# Processing Record 3 of Set 14 | siniscola
# Processing Record 4 of Set 14 | suntar
# Processing Record 5 of Set 14 | bandundu
# Processing Record 6 of Set 14 | lazarev
# Processing Record 7 of Set 14 | zhigansk
# Processing Record 8 of Set 14 | vikhorevka
# Processing Record 9 of Set 14 | ramhormoz
# Processing Record 10 of Set 14 | kavali
# Processing Record 11 of Set 14 | marzuq
# Processing Record 12 of Set 14 | oga
# Processing Record 13 of Set 14 | mamontovo
# Processing Record 14 of Set 14 | alto araguaia
# Processing Record 15 of Set 14 | micheweni
# Processing Record 16 of Set 14 | abha
# Processing Record 17 of Set 14 | diego de almagro
# Processing Record 18 of Set 14 | sassandra
# Processing Record 19 of Set 14 | shepsi
# Processing Record 20 of Set 14 | cap malheureux
# Processing Record 21 of Set 14 | kalmunai
# Processing Record 22 of Set 14 | guia de isora
# Processing Record 23 of Set 14 | santarem
# Processing Record 24 of Set 14 | huangmei
# Processing Record 25 of Set 14 | mandalgovi
# Processing Record 26 of Set 14 | atasu
# Processing Record 27 of Set 14 | vung tau
# Processing Record 28 of Set 14 | sao joao da barra
# Processing Record 29 of Set 14 | baker city
# Processing Record 30 of Set 14 | rancho veloz
# Processing Record 31 of Set 14 | kirkuk
# Processing Record 32 of Set 14 | mbandaka
# Processing Record 33 of Set 14 | semnan
# Processing Record 34 of Set 14 | portland
# Processing Record 35 of Set 14 | bowen
# Processing Record 36 of Set 14 | bonavista
# Processing Record 37 of Set 14 | porto de moz
# Processing Record 38 of Set 14 | digha
# Processing Record 39 of Set 14 | portsmouth
# Processing Record 40 of Set 14 | nevers
# Processing Record 41 of Set 14 | kinsale
# Processing Record 42 of Set 14 | goundam
# Processing Record 43 of Set 14 | lorengau
# Processing Record 44 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 14 | sakakah
# Processing Record 46 of Set 14 | baykit
# Processing Record 47 of Set 14 | avera
# Processing Record 48 of Set 14 | aksarka
# Processing Record 49 of Set 14 | ustrzyki dolne
# Processing Record 50 of Set 14 | gushi
# Processing Record 1 of Set 15 | albolote
# Processing Record 2 of Set 15 | miraflores
# Processing Record 3 of Set 15 | sola
# Processing Record 4 of Set 15 | hojo
# Processing Record 5 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 15 | hovd
# Processing Record 7 of Set 15 | kayerkan
# Processing Record 8 of Set 15 | tabou
# Processing Record 9 of Set 15 | upington
# Processing Record 10 of Set 15 | haapiti
# Processing Record 11 of Set 15 | poronaysk
# Processing Record 12 of Set 15 | bairnsdale
# Processing Record 13 of Set 15 | lazaro cardenas
# Processing Record 14 of Set 15 | el alto
# Processing Record 15 of Set 15 | eirunepe
# Processing Record 16 of Set 15 | pangody
# Processing Record 17 of Set 15 | dalbandin
# Processing Record 18 of Set 15 | dakar
# Processing Record 19 of Set 15 | luganville
# Processing Record 20 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 15 | ilam
# Processing Record 22 of Set 15 | crossville
# Processing Record 23 of Set 15 | tharad
# Processing Record 24 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 15 | ziarat
# Processing Record 26 of Set 15 | vilyuysk
# Processing Record 27 of Set 15 | sonqor
# Processing Record 28 of Set 15 | cauquenes
# Processing Record 29 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 30 of Set 15 | santa fe
# Processing Record 31 of Set 15 | itoman
# Processing Record 32 of Set 15 | gemena
# Processing Record 33 of Set 15 | iesolo
# Processing Record 34 of Set 15 | yebaishou
# Processing Record 35 of Set 15 | kabompo
# Processing Record 36 of Set 15 | cayenne
# Processing Record 37 of Set 15 | yining
# Processing Record 38 of Set 15 | narasannapeta
# Processing Record 39 of Set 15 | seoul
# Processing Record 40 of Set 15 | abdanan
# Processing Record 41 of Set 15 | taltal
# Processing Record 42 of Set 15 | colares
# Processing Record 43 of Set 15 | siguiri
# Processing Record 44 of Set 15 | jinchengjiang
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Khatanga      RU  71.9667  102.5000    -26.45        86         100
# 1         Qaanaaq      GL  77.4840  -69.3632     14.07        85          59
# 2       Hithadhoo      MV  -0.6000   73.0833     81.36        73          56
# 3         Mataura      NZ -46.1927  168.8643     60.01        64         100
# 4     Provideniya      RU  64.3833 -173.3000     10.20        93          94
# 5            Bafq      IR  31.6128   55.4107     40.30        56           0
# 6       Saskylakh      RU  71.9167  114.0833    -19.48        86         100
# 7  Campbell River      CA  50.0163 -125.2446     30.00       100          20
# 8          Polohy      UA  47.4844   36.2536     37.65        88          57
# 9       Busselton      AU -33.6500  115.3333     64.00        77           0
#
#    Wind Speed Current Description
# 0        9.26     overcast clouds
# 1        3.65       broken clouds
# 2        2.73          light rain
# 3        8.99     overcast clouds
# 4        5.46     overcast clouds
# 5       10.51           clear sky
# 6        7.90     overcast clouds
# 7        5.75          few clouds
# 8       13.06       broken clouds
# 9        7.92           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
